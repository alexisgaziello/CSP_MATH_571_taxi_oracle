# %% [markdown]
# # CS 584: Machine Learning"
# ### Alexis Gaziello

# %% [markdown]
# # Assignement 3
#
# Import necessary libraries and initialization of some variables

# %%
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt

data = pandas.read_csv('claim_history.csv', delimiter=',')
display(data)


#data_train, data_test = train_test_split(data_to_analyze, test_size=0.25, random_state=60616, stratify = data['CAR_USE'])
# Out:
#               ID  KIDSDRIV      BIRTH   AGE  HOMEKIDS   YOJ    INCOME PARENT1  \
# 0       63581743         0  16-Mar-39  60.0         0  11.0   67000.0      No
# 1      132761049         0  21-Jan-56  43.0         0  11.0   91000.0      No
# 2      921317019         0  18-Nov-51  48.0         0  11.0   53000.0      No
# 3      727598473         0   5-Mar-64  35.0         1  10.0   16000.0      No
# 4      450221861         0   5-Jun-48  51.0         0  14.0       NaN      No
# ...          ...       ...        ...   ...       ...   ...       ...     ...
# 10297   67790126         1  13-Aug-54  45.0         2   9.0  165000.0      No
# 10298   61970712         0  17-Jun-53  46.0         0   9.0  107000.0      No
# 10299  849208064         0  18-Jun-51  48.0         0  15.0   40000.0      No
# 10300  627828331         0  12-Dec-48  50.0         0   7.0   43000.0      No
# 10301  680381960         0  27-Feb-47  52.0         0  11.0   53000.0      No
#
# ...

# %% [markdown]
# ## Cleaning
