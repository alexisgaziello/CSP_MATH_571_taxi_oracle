# %%
import os, sys
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import importlib.util


# Get current path from where script is executed
if os.name == 'nt':
    sep = '\\'
elif os.name == 'posix':
    sep = '/'
else:
    print(f'What is this OS? {os.name}')

path = os.getcwd()
path_datasets = path[:-len(f'Code{sep}src{sep}project_CSP_MATH_571')] + f'DataSets{sep}trips{sep}'


#MapGenerator Lib
path_maps = path + f'{sep}mapGeneration{sep}mapGeneration.py'
spec = importlib.util.spec_from_file_location("mapGeneration", path_maps)
mp = importlib.util.module_from_spec(spec)
spec.loader.exec_module(mp)

# %% [markdown]
# ### Load Data

# %%
# Read csv
datasets = os.listdir(path_datasets)

df_list = []
for dataset in datasets:
    if dataset[-4:] == '.csv':
        df = pd.read_csv(path_datasets + dataset, index_col=None, header=0)
        df_list.append(df)


# Merge Taxis Data
df = pd.concat(df_list, axis=0, ignore_index=True)

del(df_list)

#df1 = pd.read_csv(path_datasets + 'jan-ap19.csv', delimiter=',')
#df2 = pd.read_csv(path_datasets + 'may-nov19.csv', delimiter=',')

# Merge Taxis Data of 2019
#df = pd.concat([df1,df2], axis=0, ignore_index=True)

#del(df1)
#del(df2)

df.head()
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                  unique_key  \
# 0  ececa29f7a1392f7d937f34a2040f409744d0354
# 1  1fbf17a48aca428fefc0a79d0218ed729ea7e8e3
# 2  73eab95221395356ad45ce8b7a8716bcddb4c034
# 3  701fcdd02b0dd0dc01cbffcd7c2c9572386f5966
# 4  2984246ff88a9e42cb7d80d5a056a91592cd2103
#
#                                              taxi_id     trip_start_timestamp  \
# 0  8d1222551aa0783ed24c0941a29222b21fe66e643a801a...  2019-01-17 11:30:00 UTC
# 1  c0efb2f0d92d8721d64fcd6628a9f8e78b7693cb5f36ee...  2019-03-02 09:45:00 UTC
# 2  5e00ac77728ae1790a517495300680a2ff69fe9a569218...  2019-02-12 11:15:00 UTC
# 3  e5e1bb9c3329c0f9bd1f291cb9bbbb016731c148fefca8...  2019-02-15 03:30:00 UTC
# 4  0574d247700e50d1fb996084c8b1c649bf57effe419a6d...  2019-02-27 07:00:00 UTC
#
#         trip_end_timestamp  trip_seconds  trip_miles  pickup_census_tract  \
# 0  2019-01-17 12:00:00 UTC        1363.0       15.50                  NaN
# 1  2019-03-02 10:45:00 UTC        2754.0       13.73                  NaN
# 2  2019-02-12 12:15:00 UTC        3422.0       31.77                  NaN
# 3  2019-02-15 03:45:00 UTC        1302.0       10.16                  NaN
# 4  2019-02-27 07:45:00 UTC        2308.0       14.26                  NaN
#
#    dropoff_census_tract  pickup_community_area  dropoff_community_area  ...  \
# 0                   NaN                   41.0                     NaN  ...
# 1                   NaN                   46.0                     NaN  ...
# 2                   NaN                    8.0                     NaN  ...
# 3                   NaN                    8.0                     NaN  ...
# 4                   NaN                    8.0                     NaN  ...
#
#    extras  trip_total  payment_type    company  pickup_latitude  \
# 0     0.0        38.5          Cash  Flash Cab        41.794090
# 1     0.0        37.5          Cash  Flash Cab        41.741243
# 2     0.0        76.5          Cash  Flash Cab        41.899602
# 3     0.0        26.5          Cash  Flash Cab        41.899602
# 4     3.5        41.0          Cash  Flash Cab        41.899602
#
#   pickup_longitude                      pickup_location  dropoff_latitude  \
# 0       -87.592311   POINT (-87.592310855 41.794090253)               NaN
# 1       -87.551428  POINT (-87.551428197 41.7412427285)               NaN
# 2       -87.633308  POINT (-87.6333080367 41.899602111)               NaN
# 3       -87.633308  POINT (-87.6333080367 41.899602111)               NaN
# 4       -87.633308  POINT (-87.6333080367 41.899602111)               NaN
#
#    dropoff_longitude dropoff_location
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (8498882, 23)

# %% [markdown]
# For testing:

# %%
df_sampled = df.sample(n=400_000, random_state=1)
df_sampled_a_lot = df.sample(n=1_000, random_state=1)

# %% [markdown]
# ### Some information about the dataset

# %%
qty_taxis = len(df['taxi_id'].drop_duplicates())
print(f'Quantity of taxis: {qty_taxis}')
# Out:
# Quantity of taxis: 1167

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8498882 entries, 0 to 8498881
# Data columns (total 23 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   unique_key              object
#  1   taxi_id                 object
#  2   trip_start_timestamp    object
#  3   trip_end_timestamp      object
#  4   trip_seconds            float64
#  5   trip_miles              float64
#  6   pickup_census_tract     float64
#  7   dropoff_census_tract    float64
#  8   pickup_community_area   float64
#  9   dropoff_community_area  float64
#  10  fare                    float64
#  11  tips                    float64
#  12  tolls                   float64
#  13  extras                  float64
#  14  trip_total              float64
#  15  payment_type            object
#  16  company                 object
#  17  pickup_latitude         float64
#  18  pickup_longitude        float64
#  19  pickup_location         object
#  20  dropoff_latitude        float64
#  21  dropoff_longitude       float64
#  22  dropoff_location        object
# dtypes: float64(15), object(8)
# memory usage: 1.5+ GB

# %%
df['trip_start_timestamp'] = pd.to_datetime(df['trip_start_timestamp'],format=r"%Y-%m-%d %H:%M:%S UTC")
df['trip_end_timestamp'] = pd.to_datetime(df['trip_end_timestamp'],format=r"%Y-%m-%d %H:%M:%S UTC")

# %% [markdown]
# ### Preprocessing: Missing Values

# %% [markdown]
# We are not interested in NaN values in the Target Variable **(pickup_community_area)**

# %%
df = df.dropna(subset=['pickup_community_area'])

# %% [markdown]
# **Check the below assumption**

# %%
df = df.dropna(subset=['dropoff_community_area'])

# %%
df.shape
# Out:
# (7665012, 23)

# %%
df.loc[:,'pickup_community_area'] = df.loc[:,'pickup_community_area'].astype('int64')
df.loc[:,'dropoff_community_area'] = df.loc[:,'dropoff_community_area'].astype('int64')

# %% [markdown]
# **Drop useless columns**

# %%
df = df.drop(columns=['company', 'pickup_latitude','pickup_longitude', 'pickup_location', 'dropoff_latitude',
                       'dropoff_longitude', 'dropoff_location'])

# %% [markdown]
# **Checking percentage of missing values**

# %%
100 * df.isnull().sum()/df.shape[0]
# Out:
# unique_key                 0.000000
# taxi_id                    0.000000
# trip_start_timestamp       0.000000
# trip_end_timestamp         0.000000
# trip_seconds               0.005062
# trip_miles                 0.000130
# pickup_census_tract       36.525853
# dropoff_census_tract      36.525853
# pickup_community_area      0.000000
# dropoff_community_area     0.000000
# fare                       0.000130
# tips                       0.000130
# tolls                     77.495599
# extras                     0.000130
# trip_total                 0.000130
# payment_type               0.000000
# dtype: float64

# %% [markdown]
# As we can see in the dataset description, pickup_census_tract and dropoff_census_tract have a high number of missing values due to user privacy, so we delete these columns.

# %%
df = df.drop(columns=['pickup_census_tract','dropoff_census_tract'])

# %% [markdown]
# #### Tolls
#
# This value shouldn't be missing due to privacy. Let's check the possible values.

# %%
df['tolls'].unique()
# Out:
# array([nan,  0.])

# %%
df['tolls'].isna().sum()
# Out:
# 5940047

# %% [markdown]
# 'tolls' should be a predictor that indicates if the trip went through a toll. As we can see in the above cell, the values are just 0 or nan.
#
# Let's get insight in the trips where the values are nan.

# %% [markdown]
# *Time Analysis*

# %%
# Randomly group by start timestamp
df.index = df['trip_start_timestamp']
# Total elements
timeStart_grouped = df.groupby(pd.Grouper(freq='M'))
# Total NA elements
timeStart_tollNA_grouped = df.loc[df['tolls'].isna(),].groupby(pd.Grouper(freq='M'))

# Percentaje
y = 100 * timeStart_tollNA_grouped.size()/timeStart_grouped.size()
y = y[~y.isna()]

# Plot
plt.figure(figsize=(10,5))
plt.fill_between(y.index, y, color='blue', alpha=0.5)
plt.plot(y, color='red')
plt.grid()
plt.xticks(rotation=25, ha='right')
plt.xlabel('Date')
plt.ylabel('% of missing NA Toll')

plt.show()

# %% [markdown]
# As we can see, a little before 2019 values stopped being NAs. This is probably a new value that was added recently to the dataset.

# %% [markdown]
# Let's check the distribution prior to 2019, to see if it's random or maybe only some communities started using it.

# %%
plt.figure(figsize=(12,5))
plt.hist([df.loc[df['tolls'].isna(),'dropoff_community_area']
          , df['dropoff_community_area']]
          , density=True
          , color=['blue','red']
          , label= ['Dropoff Distribution of Tolls NAN Values','Dropoff Distribution']
          , bins=20)

plt.xlabel('Dropoff Community Area')
plt.ylabel('Decimal fraction')
plt.legend()
plt.show()

# %% [markdown]
# As we can see in the above plot, the distribution of dropoff in the missing tolls samples is very similar to the whole distribution. Out assumption is that missed tolls is not related to the trip, so these nan values are random and we assume that all values are 0. Therefore this predictor does not provide any information, so we drop it.
#
# Our hypothesis is that since in Chicago there are no many tolls, no taxi uses them.

# %%
df = df.drop(columns='tolls')

# %% [markdown]
# #### trip_miles, fare, tips, extras & trip_total

# %% [markdown]
# Due to the percentage of missing values of these columns is the same, we are going to check if the values are missing in the same rows.

# %%
n_missing = (df['trip_miles'].isna()).sum()

# %%
n_missing
# Out:
# 10

# %%
cols_same_na = ['trip_miles','fare','tips','extras','trip_total']

index = df['trip_miles'].isna()
for i in range(1,len(cols_same_na)):
    index &= (df[cols_same_na[i]].isna())

result = 'They are the same rows! :)' if index.sum() == n_missing else "They are different rows :("
print(result)
# Out:
# They are the same rows! :)

# %% [markdown]
# As we see all columns missing in the same rows. Since 10 samples in a couple of millions is insignificant, we delete these 10 samples

# %%
df = df[~index]

# %% [markdown]
# #### trip_seconds

# %%
dropCA_tripSecNA = df.loc[df['trip_seconds'].isna(),'dropoff_community_area']
dropCA = df['dropoff_community_area']

plt.figure(figsize=(12,5))
plt.hist([dropCA_tripSecNA,dropCA]
         ,density=True
         ,color=['blue','red']
         ,label=['Dropoff Distribution of Trip Seconds NAN Values','Dropoff Distribution']
         ,bins=20)

plt.xlabel('Dropoff Community Area')
plt.ylabel('Decimal fraction')
plt.legend()
plt.show()

# %% [markdown]
# As we can see, the distribution of missing values in this columns seems to be random. We are going to replace them with the mean of similar trips (i.e same pick_up and dropoff community area)

# %%
def getMeanTripSeconds(row):
    
    index = (df['pickup_community_area'] == row['pickup_community_area'])
    index &= (df['dropoff_community_area'] == row['dropoff_community_area'])
    mean = df.loc[index,'trip_seconds'].mean()
    
    return mean

# %%
estimatedTripSec = df.loc[df['trip_seconds'].isna(),['pickup_community_area','dropoff_community_area']].apply(lambda row : getMeanTripSeconds(row), axis=1)

# %%
df.loc[df['trip_seconds'].isna(),'trip_seconds'] = estimatedTripSec

# %%
df.isna().sum()
# Out:
# unique_key                0
# taxi_id                   0
# trip_start_timestamp      0
# trip_end_timestamp        0
# trip_seconds              0
# trip_miles                0
# pickup_community_area     0
# dropoff_community_area    0
# fare                      0
# tips                      0
# extras                    0
# trip_total                0
# payment_type              0
# dtype: int64

# %% [markdown]
# ### Preprocessing: Check Errors

# %% [markdown]
# **Time Consistency**
#
# Check how long trips usually take
#
# *Note: (end-start != duration), because the end and start are rounded to the nearest 15 minutes.*

# %%
fig, ax = plt.subplots(figsize=(5,10))
ax.boxplot(df['trip_seconds']/3600)
ax.set_title('Duration of trip in hours')
ax.set_ylabel('Hours')
plt.show()

# %% [markdown]
# We are working with so much data that the outliers won't let visualize correctly the boxplot.
# As we can see there are taxi rides that last nearly a full day. However this can be possible. Maybe somebody who wouldn't mind paying lot's of money to get a private car. Of course the best way to ensure this is to contact the company.

# %%
q1, q3 = df['trip_seconds'].quantile([0.25, 0.75])
topWhisker = q3+1.5*(q3-q1)
qty = len(df.loc[df['trip_seconds'] > topWhisker,])
print(f'Quantity of outliers (>{topWhisker*60} mins): {qty}\nPercentaje: {round(qty/len(df)*100,2)}%')

hours = 3
qty = len(df.loc[df['trip_seconds'] > hours*3600,])
print(f'Quantity of trips that lasted more than {hours}h: {qty}\nPercentaje: {round(qty/len(df)*100,2)}%')
# Out:
# Quantity of outliers (>116010.0 mins): 630259
# Percentaje: 8.22%
# Quantity of trips that lasted more than 3h: 2685
# Percentaje: 0.04%

# %% [markdown]
# Let's check the histogram of outliers:

# %%
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(20,10))

ax[0].hist(df['trip_seconds']/3600,density=True)
ax[0].set_title(f'Histogram of trips')
ax[0].set_ylabel('Decimal Fraction')
ax[0].set_xlabel('Hours')


ax[1].hist(df.loc[df['trip_seconds'] > hours*3600,]['trip_seconds']/3600,density=True,bins=30)
ax[1].set_title(f'Histogram of trips which have a duration of more than {hours} hours')
ax[1].set_ylabel('Decimal Fraction')
ax[1].set_xlabel('Hours')
plt.show()

# %% [markdown]
# There is a huge decrease on taxi trips that last more than around 5 hours. It is curious the distribution around 16 hours of trips...

# %% [markdown]
# Let's visualize the boxplot without the outliers to get a better visualization of tipical values.

# %%
fig, ax = plt.subplots(figsize=(5,7))
ax.boxplot(df['trip_seconds']/60, showfliers=False)
ax.set_title('Duration of trip in minutes')
ax.set_ylabel('Minutes')
plt.show()

# %% [markdown]
# As we can see, there are many trips that last less than 10 seconds. Trips that were maybe cancelled? Should we take them off? We are not interested in predicting trips that will be canceled. Where is the correct threshold to assume that a trip was canceled?

# %%
fig, ax = plt.subplots(figsize=(7,8))

plt.hist(df.loc[df['trip_seconds'] < 60,'trip_seconds'],density=True)
ax.set_title('Distribution of Trips less than 1 minute')
ax.set_xlabel('Seconds')

plt.show()

# %%
#Trips of 0 seconds
df[df['trip_seconds'] == 0].shape[0]
# Out:
# 13594

# %%
df_less1Min = df[df['trip_seconds'] < 60]

# %% [markdown]
# *Time Analysis*

# %%
y = 100 * df_less1Min.groupby(pd.Grouper(freq='M')).size() / df.groupby(pd.Grouper(freq='M')).size()

# Plot
plt.figure(figsize=(10,5))
plt.fill_between(y.index, y, color='blue', alpha=0.5)
plt.plot(y, color='red')
plt.grid()
plt.xticks(rotation=25, ha='right')
plt.xlabel('Date')
plt.ylabel('% of Trips less 1 Min Toll')

plt.show()

# %% [markdown]
# It seems that these trips appear randomly during the 3 years. There is a peak in 2020, but it does not seem important (<5%).

# %% [markdown]
# Let's check the relation with miles and fare

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2,figsize=(15,8))

ax[0].scatter(df_less1Min['trip_miles'], df_less1Min['trip_seconds'], marker='.', alpha=0.5)
ax[0].set_title('Relation Miles-Duration in Trips (duration < 1 min)')
ax[0].set_ylabel('Duration in seconds')
ax[0].set_xlabel('Miles')

ax[1].scatter(df_less1Min['fare'], df_less1Min['trip_seconds'], marker='.', alpha=0.5)
ax[1].set_title('Relation Fare-Duration in Trips (duration < 1 min)')
ax[1].set_ylabel('Duration in seconds')
ax[1].set_xlabel('Fare')
plt.show()

# %%
df_less1Min = df[(df['trip_seconds'] > 10) & (df['trip_seconds'] < 60)]

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 3,figsize=(20,8))

ax[0].scatter(df_less1Min['trip_miles'], df_less1Min['trip_seconds'], marker='.', alpha=0.5)
ax[0].set_title('Relation Miles-Duration in Trips (duration >10 sec & < 1 min)')
ax[0].set_ylabel('Duration in seconds')
ax[0].set_xlabel('Miles')

ax[1].scatter(df_less1Min['fare'], df_less1Min['trip_seconds'], marker='.', alpha=0.5)
ax[1].set_title('Relation Fare-Duration in Trips (duration >10 sec & < 1 min)')
ax[1].set_ylabel('Duration in seconds')
ax[1].set_xlabel('Fare')

ax[2].scatter(df_less1Min['fare'], df_less1Min['trip_miles'], marker='.', alpha=0.5)
ax[2].set_title('Relation Fare-Miles in Trips (duration >10 sec & < 1 min)')
ax[2].set_ylabel('Miles')
ax[2].set_xlabel('Fare')
plt.show()

# %%
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(16,7))
ax[0].scatter(df['trip_miles'], df['trip_seconds'], marker='.', alpha=0.5)
ax[0].set_title('Relation Miles-Duration in Trips')
ax[0].set_ylabel('Duration in seconds')
ax[0].set_xlabel('Miles')

df_sampled_a_lot = df_sampled_a_lot.loc[df_sampled_a_lot['trip_seconds'] <10_000,]
ax[1].scatter(df_sampled_a_lot['trip_miles'], df_sampled_a_lot['trip_seconds'], marker='.', alpha=0.5)
ax[1].set_title('Relation Miles-Duration in Trips without outliers')
ax[1].set_ylabel('Duration in seconds')
ax[1].set_xlabel('Miles')
plt.show()

# %%
# Miles-Fare Relationship for Flash Cab Company
mileFareRel = (np.arange(0,36) * 2.25) + 3.25

# %%
mileFareRel
# Out:
# array([ 3.25,  5.5 ,  7.75, 10.  , 12.25, 14.5 , 16.75, 19.  , 21.25,
#        23.5 , 25.75, 28.  , 30.25, 32.5 , 34.75, 37.  , 39.25, 41.5 ,
#        43.75, 46.  , 48.25, 50.5 , 52.75, 55.  , 57.25, 59.5 , 61.75,
#        64.  , 66.25, 68.5 , 70.75, 73.  , 75.25, 77.5 , 79.75, 82.  ])

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2,figsize=(15,8))

df_FareMilesClean = df[(df['fare'] > 0) & (df['fare'] < 200) & (df['trip_miles'] > 0) & (df['trip_miles'] < 35)]

ax[0].plot(mileFareRel,color='red',label='Real Relation')
ax[0].scatter(df_FareMilesClean['trip_miles'],df_FareMilesClean['fare'], marker='.', alpha=0.5)
ax[0].set_title('Relation Fare-Miles whitout outliers')
ax[0].set_ylabel('Fare')
ax[0].set_xlabel('Miles')
ax[0].legend(loc='upper right')

df_less1MinClean = df_less1Min[(df_less1Min['fare'] > 0) & (df_less1Min['fare'] < 200) & (df_less1Min['trip_miles'] > 0) & (df_less1Min['trip_miles'] < 35)]
ax[1].plot(mileFareRel,color='red',label='Real Relation')
ax[1].scatter(df_less1MinClean['trip_miles'],df_less1MinClean['fare'], marker='.', alpha=0.5)
ax[1].set_title('Relation Fare-Miles in Trips (duration >10 sec & < 1 min) whitout outliers')
ax[1].set_ylabel('Fare')
ax[1].set_xlabel('Miles')
ax[1].legend(loc='upper right')

plt.show()

# %% [markdown]
# Some of the conclusions of the above plots:
# - We can see a relation between Time-Miles
# - We can see most of the data follow the real relationship Fare-Miles.
# - We conclude that the *trip_seconds* of short trips (less than 1 minute) are wrong, due to does not follow the relation of the whole dataset
# - In the whole dataset there are plenty of errors that does not follow the linear relationship between Fare-Miles. It is true that data points located in the upper side of this line, could be due to a high traffic but values below to this line seem to be errors in any of these columns.
#
# These conclusions encourage us, to delete the samples where the fare is less than the minimum real value, since they are incorrect data.

# %% [markdown]
# Flash Cab Fare Calculation: https://www.taxiautofare.com/us/taxi-fare-card/Chicago-Flash-Cab-fare

# %%
def cmpFareRealValue(row):
    min_val = (row['trip_miles']* 2.25) + 3.25
    max_val = min_val + 0.2*row['trip_seconds'] #As the cab were stopped the whole trip
    return (row['fare'] >= min_val) & (row['fare'] < max_val)

# %%
index = df.apply(lambda row : cmpFareRealValue(row),axis=1)

# %%
print("% of Wrong Fare Data: {:.2f}%".format(100 * (~index).sum()/df.shape[0]))
# Out:
# % of Wrong Fare Data: 99.78%

# %%
df = df[index]

# %%
fig, ax = plt.subplots(nrows= 1, ncols=2, figsize=(15,7))

df_FareMilesClean = df[(df['fare'] > 0) & (df['fare'] < 200) & (df['trip_miles'] > 0) & (df['trip_miles'] < 35)]

ax[0].plot(mileFareRel,color='red',label='Real Relation')
ax[0].scatter(df_FareMilesClean['trip_miles'],df_FareMilesClean['fare'], marker='.', alpha=0.5)
ax[0].set_title('Relation Fare-Miles whitout outliers')
ax[0].set_ylabel('Fare')
ax[0].set_xlabel('Miles')
ax[0].legend(loc='upper right')

df_sampled_a_lot = df[(df['trip_seconds'] < 10_000) & (df['trip_miles'] > 0) & (df['trip_miles'] < 35)]
ax[1].scatter(df_sampled_a_lot['trip_miles'], df_sampled_a_lot['trip_seconds'], marker='.', alpha=0.5)
ax[1].set_title('Relation Miles-Duration in Trips without outliers')
ax[1].set_ylabel('Duration in seconds')
ax[1].set_xlabel('Miles')


plt.show()

# %% [markdown]
# **DANI CHECK**

# %% [markdown]
# **Miles consistency**
#
# Check average miles in trips

# %%
fig, ax = plt.subplots(figsize=(5,10))
ax.boxplot(df['trip_miles'])
ax.set_title('Miles driven')
ax.set_ylabel('Miles')
plt.show()

# %% [markdown]
# Here we can see there are also many outliers. However, compared to the time, these seem much more concentrated near the top whisker. This make sense. Trips of more than 50 miles in Chicago don't make much sense. It could be interesting to check if long trips durations are correlated with long trips miles.

# %% [markdown]
# **CHECK TRIPS DE MAS DE 200??**
#
# Atrvesar Illinois de punta a punta son 250 miles. Chicago tendra unas 30 miles de largo como mucho.

# %% [markdown]
# Let's visualize the boxplot without the outliers to get a better visualization of tipical values.

# %%
fig, ax = plt.subplots(figsize=(5,7))
ax.boxplot(df['trip_miles'], showfliers=False)
ax.set_title('Miles driven')
ax.set_ylabel('Miles')
plt.show()

# %% [markdown]
# **LO mismo THRESHOLD PARA UNA LONGITUD MINIMA? 50m aunque sea**

# %% [markdown]
# **Correlation**
#
# - Trips with ++ miles   **&Implies;**  ++ time &emsp; (or at least, if we consider a average speed speed of 20 miles/hour, for every mile, there should be at least 3600/20 seconds)
# - Trips with -- miles  **&Implies;** -- time
#
#
# - Trips with ++ time **&Implies;** ++ miles. *This is not necessarily true. The taxi could have been waiting.*
# - Trips with -- time **&Implies;** -- miles.
#
# Check if in average, time corresponds to an aproximate quantity of miles, taking an average speed.

# %% [markdown]
# **Una vez más, los outliers se cargan todo**

# %%
fig, ax = plt.subplots(figsize=(7,7))
ax.scatter(df['trip_miles'], df['trip_seconds'], marker='.', alpha=0.5)
ax.set_title('Scatter plot')
ax.set_ylabel('Duration in seconds')
ax.set_xlabel('Miles')
plt.show()

# %% [markdown]
# Si nos petamos los outliers si hay una relación:

# %%
fig, ax = plt.subplots(figsize=(7,7))
df_sampled_a_lot = df_sampled_a_lot.loc[df_sampled_a_lot['trip_seconds'] <10_000,]
ax.scatter(df_sampled_a_lot['trip_miles'], df_sampled_a_lot['trip_seconds'], marker='.', alpha=0.5)
ax.set_title('Scatter plot')
ax.set_ylabel('Duration in seconds')
ax.set_xlabel('Miles')
plt.show()

# %% [markdown]
# Hacer lo mismo con 'fare', 'trip_total', tips'
# Analizar 'payment_type'

# %% [markdown]
# y ya con eso habríamos terminado. Guardar el dataset en binario o csv y volver a abrirlo en otro notebook para unirlo con el weather y holidays limpio para empezar a hacer data analysisç

# %% [markdown]
# **KAGGLES TASKS**
#
# (interesante)

# %% [markdown]
# - Taxi company usually used in Chicago
# - Mode of payment usually used

# %% [markdown]
# - Outliers: Cost, Time...
# - Box Plot trip miles by type of

# %%
df.shape
# Out:
# (7665002, 13)

# %%
(df['trip_end_timestamp'][2]-df['trip_start_timestamp'][2]).seconds
# Out:
# 900

# %%
df['trip_seconds'][2]
# Out:
# 328.0

# %%
mp.mapGeneratorFromDict(Counter(df_cleaned['pickup_community_area']), cmap=0)

# %%
mp.mapGeneratorFromDict(Counter(df_cleaned['dropoff_community_area']), cmap=0)

# %%
b = df_cleaned.loc[df_cleaned['pickup_community_area'] == 55]
a = Counter(b['dropoff_community_area'])
mp.mapGeneratorFromDict(a, cmap=0)

# %%
print(len(df_cleaned.loc[df_cleaned['dropoff_community_area'] != df_cleaned['pickup_community_area']]))
print(len(df_cleaned))
# Out:
# 454309
# 655917

# %%
pickups = Counter(df_cleaned['pickup_community_area'])

array = []
counter = 1
while(len(array) < 77):
    # Check if value exists
    if counter in pickups:
        array += [pickups[counter]]
    else:
        array += [0]

    counter += 1
    
print (len(array))
# Out:
# 77

# %%
for name in dir():
    if not name.startswith('_'):
        print(globals()[name])
# Out:
# <class 'collections.Counter'>
# ['', 'import os, sys\nimport pandas as pd\nimport math\nimport numpy as np\nimport matplotlib.pyplot as plt\nimport seaborn as sns\nfrom collections import Counter\nimport importlib.util\n\n\n# Get current path from where script is executed\nif os.name == \'nt\':\n    sep = \'\\\\\'\nelif os.name == \'posix\':\n    sep = \'/\'\nelse:\n    print(f\'What is this OS? {os.name}\')\n\npath = os.getcwd()\npath_datasets = path[:-len(f\'Code{sep}src{sep}project_CSP_MATH_571\')] + f\'DataSets{sep}trips{sep}\'\n\n\n#MapGenerator Lib by Alexitoh96\npath_maps = path + f\'{sep}mapGeneration{sep}mapGeneration.py\'\nspec = importlib.util.spec_from_file_location("mapGeneration", path_maps)\nmp = importlib.util.module_from_spec(spec)\nspec.loader.exec_module(mp)', "# Read csv\ndatasets = os.listdir(path_datasets)\n\ndf_list = []\nfor dataset in datasets:\n    if dataset[-4:] == '.csv':\n        df = pd.read_csv(path_datasets + dataset, index_col=None, header=0)\n        df_list.append(df)\n\n\n# Merge Taxis Data\ndf = pd.concat(df_list, axis=0, ignore_index=True)\n\ndel(df_list)\n\n#df1 = pd.read_csv(path_datasets + 'jan-ap19.csv', delimiter=',')\n#df2 = pd.read_csv(path_datasets + 'may-nov19.csv', delimiter=',')\n\n# Merge Taxis Data of 2019\n#df = pd.concat([df1,df2], axis=0, ignore_index=True)\n\n#del(df1)\n#del(df2)\n\ndf.head()", 'df.shape', "qty_taxis = len(df['taxi_id'].drop_duplicates())\nprint(f'Quantity of taxis: {qty_taxis}')", 'df.info()', 'df[\'trip_start_timestamp\'] = pd.to_datetime(df[\'trip_start_timestamp\'],format=r"%Y-%m-%d %H:%M:%S UTC")\ndf[\'trip_end_timestamp\'] = pd.to_datetime(df[\'trip_end_timestamp\'],format=r"%Y-%m-%d %H:%M:%S UTC")', "df.dropna(subset=['pickup_community_area'], inplace=True)", "df.dropna(subset=['dropoff_community_area'], inplace=True) ", 'df.shape', "df.loc[:,'pickup_community_area'] = df.loc[:,'pickup_community_area'].astype('int64')\ndf.loc[:,'dropoff_community_area'] = df.loc[:,'dropoff_community_area'].astype('int64')", "df.drop(columns=['company', 'pickup_latitude','pickup_longitude', 'pickup_location', 'dropoff_latitude',\n                       'dropoff_longitude', 'dropoff_location'],inplace=True)", "df = df.dropna(subset=['pickup_community_area'])", "df = df.dropna(subset=['dropoff_community_area']) ", '100 * df.isnull().sum()/df.shape[0]', "df['tolls'].unique()", "df['tolls'].isna().sum()", "# Randomly group by start timestamp\ndf.index = df['trip_start_timestamp']\n# Total elements\ntimeStart_grouped = df.groupby(pd.Grouper(freq='M'))\n# Total NA elements\ntimeStart_tollNA_grouped = df.loc[df['tolls'].isna(),].groupby(pd.Grouper(freq='M'))\n\n# Percentaje\ny = 100 * timeStart_tollNA_grouped.size()/timeStart_grouped.size()\ny = y[~y.isna()]\n\n# Plot\nplt.figure(figsize=(10,5))\nplt.plot(y)\nplt.xticks(rotation=70, ha='right')\nplt.xlabel('Date')\nplt.ylabel('% of missing NA Toll')\n\nplt.show()", 'As we can see, a little before 2019 values stopped being NAs. This is probably a new value that was added recently to the dataset.', "dropCA_tollNA = df.loc[df['tolls'].isna(),'dropoff_community_area']\ndropCA = df['dropoff_community_area']\n\ncolors = ['blue','red']\nlabels = ['Dropoff Distribution of Tolls NAN Values','Dropoff Distribution']\n\nplt.figure(figsize=(12,5))\nplt.hist([dropCA_tollNA, dropCA],density=True,color=colors,label=labels,bins=20)\nplt.xlabel('Dropoff Community Area')\nplt.legend()\nplt.show()", "df.drop(columns='tolls',inplace=True)", "df = df.drop(columns='tolls')", "n_missing = (df['trip_miles'].isna()).sum()", 'n_missing', 'cols_same_na = [\'trip_miles\',\'fare\',\'tips\',\'extras\',\'trip_total\']\n\nindex = df[\'trip_miles\'].isna()\nfor i in range(1,len(cols_same_na)):\n    index &= (df[cols_same_na[i]].isna())\n\nresult = \'They are the same rows! :)\' if index.sum() == n_missing else "They are different rows :("\nprint(result)', 'df = df[~index]', "dropCA_tripSecNA = df.loc[df['trip_seconds'].isna(),'dropoff_community_area']\ndropCA = df['dropoff_community_area ...
# {2:                                  unique_key  \
# 0  ececa29f7a1392f7d937f34a2040f409744d0354
# 1  1fbf17a48aca428fefc0a79d0218ed729ea7e8e3
# 2  73eab95221395356ad45ce8b7a8716bcddb4c034
# 3  701fcdd02b0dd0dc01cbffcd7c2c9572386f5966
# 4  2984246ff88a9e42cb7d80d5a056a91592cd2103
#
#                                              taxi_id     trip_start_timestamp  \
# 0  8d1222551aa0783ed24c0941a29222b21fe66e643a801a...  2019-01-17 11:30:00 UTC
# 1  c0efb2f0d92d8721d64fcd6628a9f8e78b7693cb5f36ee...  2019-03-02 09:45:00 UTC
# 2  5e00ac77728ae1790a517495300680a2ff69fe9a569218...  2019-02-12 11:15:00 UTC
# 3  e5e1bb9c3329c0f9bd1f291cb9bbbb016731c148fefca8...  2019-02-15 03:30:00 UTC
# 4  0574d247700e50d1fb996084c8b1c649bf57effe419a6d...  2019-02-27 07:00:00 UTC
#
#         trip_end_timestamp  trip_seconds  trip_miles  pickup_census_tract  \
# 0  2019-01-17 12:00:00 UTC        1363.0       15.50                  NaN
# 1  2019-03-02 10:45:00 UTC        2754.0       13.73                  NaN
# 2  2019-02-12 12:15:00 UTC        3422.0       31.77                  NaN
# 3  2019-02-15 03:45:00 UTC        1302.0       10.16                  NaN
# 4  2019-02-27 07:45:00 UTC        2308.0       14.26                  NaN
#
#    dropoff_census_tract  pickup_community_area  dropoff_community_area  ...  \
# 0                   NaN                   41.0                     NaN  ...
# 1                   NaN                   46.0                     NaN  ...
# 2                   NaN                    8.0                     NaN  ...
# 3                   NaN                    8.0                     NaN  ...
# 4                   NaN                    8.0                     NaN  ...
#
#    extras  trip_total  payment_type    company  pickup_latitude  \
# 0     0.0        38.5          Cash  Flash Cab        41.794090
# 1     0.0        37.5          Cash  Flash Cab        41.741243
# 2     0.0        76.5          Cash  Flash Cab        41.899602
# 3     0.0        26.5          Cash  Flash Cab        41.899602
# 4     3.5        41.0          Cash  Flash Cab        41.899602
#
#   pickup_longitude                      pickup_location  dropoff_latitude  \
# 0       -87.592311   POINT (-87.592310855 41.794090253)               NaN
# 1       -87.551428  POINT (-87.551428197 41.7412427285)               NaN
# 2       -87.633308  POINT (-87.6333080367 41.899602111)               NaN
# 3       -87.633308  POINT (-87.6333080367 41.899602111)               NaN
# 4       -87.633308  POINT (-87.6333080367 41.899602111)               NaN
#
#    dropoff_longitude dropoff_location
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN
#
# [5 rows x 23 columns], 3: (8498882, 23), 9: (7665012, 23), 14: unique_key                 0.000000
# taxi_id                    0.000000
# trip_start_timestamp       0.000000
# trip_end_timestamp         0.000000
# trip_seconds               0.005062
# trip_miles                 0.000130
# pickup_census_tract       36.525853
# dropoff_census_tract      36.525853
# pickup_community_area      0.000000
# dropoff_community_area     0.000000
# fare                       0.000130
# tips                       0.000130
# tolls                     77.495599
# extras                     0.000130
# trip_total                 0.000130
# payment_type               0.000000
# dtype: float64, 15: array([nan,  0.]), 16: 5940047, 23: 10, 30:                                  unique_key  \
# 0  ececa29f7a1392f7d937f34a2040f409744d0354
# 1  1fbf17a48aca428fefc0a79d0218ed729ea7e8e3
# 2  73eab95221395356ad45ce8b7a8716bcddb4c034
# 3  701fcdd02b0dd0dc01cbffcd7c2c9572386f5966
# 4  2984246ff88a9e42cb7d80d5a056a91592cd2103
#
#                                              taxi_id     trip_start_timestamp  \
# 0  8d1222551aa0783ed24c0941a29222b21fe66e643a801a...  2019-01-17 11:30:00 UTC
# 1  c0efb2f0d92d8721d64fcd6628a9f8e78b7693cb5f36ee...  2019-03-02 09:45:00 UTC
# 2  5e00ac77728ae1790a517495300680a2ff69fe9a569218...  2019-02-12 11:15:00 UTC
# 3  e5e1bb9c3329c0f9bd1f291cb9bbbb016731c148fefca8...  2019-02-15 03:30:00 UTC
# 4  0574d247700e50d1fb996084c8b1c649bf57effe419a6d...  2019-02-27 07:00:00 UTC
#
#         trip_end_timestamp  trip_seconds  trip_miles  pickup_census_tract  \
# 0  2019-01-17 12:00:00 UTC        1363.0       15.50                  NaN
# 1  2019-03-02 10:45:00 UTC        2754.0       13.73                  NaN
# 2  2019-02-12 12:15:00 UTC        3422.0       31.77                  NaN
# 3  2019-02-15 03:45:00 UTC        1302.0       10.16                  NaN
# 4  2019-02-27 07:45:00 UTC        2308.0       14.26                  NaN
#
#    dropoff_census_tract  pickup_community_area  dropoff_community_area  ...  \
# 0                   NaN                   41.0                     NaN  ...
# 1                   NaN                   46.0                     NaN  ...
# 2                   NaN                    8.0                     NaN  ...
# 3                   NaN                    8.0                     NaN  ...
# 4                   NaN                    8.0                     NaN  ...
#
#    extras  trip_total  payment_type    company  pickup_latitude  \
# 0     0.0        38.5          Cash  Flash Cab        41.794090
# 1     0.0        37.5          Cash  Flash Cab        41.741243
# 2     0.0        76.5          Cash  Flash Cab        41.899602
# 3     0.0        26.5          Cash  Flash Cab        41.899602
# 4     3.5        41.0          Cash  Flash Cab        41.899602
#
#   pickup_longitude                      pickup_location  dropoff_latitude  \
# 0       -87.592311   POINT (-87.592310855 41.794090253)               NaN
# 1       -87.551428  POINT (-87.551428197 41.7412427285)               NaN
# 2       -87.633308  POINT (-87.6333080367 41.899602111)               NaN
# 3       -87.633308  POINT (-87.6333080367 41.899602111)               NaN
# 4       -87.633308  POINT (-87.6333080367 41.899602111)               NaN
#
#    dropoff_longitude dropoff_location
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN
#
# [5 rows x 23 columns], 31: (8498882, 23), 37: (7665012, 23), 40: unique_key                 0.000000
# taxi_id                    0.000000
# trip_start_timestamp       0.000000
# trip_end_timestamp         0.000000
# trip_seconds               0.005062
# trip_miles                 0.000130
# pickup_census_tract       36.525853
# dropoff_census_tract      36.525853
# pickup_community_area      0.000000
# dropoff_community_area     0.000000
# fare                       0.000130
# tips                       0.000130
# tolls                     77.495599
# extras                     0.000130
# trip_total                 0.000130
# payment_type               0.000000
# dtype: float64, 42: array([nan,  0.]), 43: 5940047}
# ['blue', 'red']
# ['trip_miles', 'fare', 'tips', 'extras', 'trip_total']
# jan-may17.csv
# ['jan-ap19.csv', 'Icon\r', 'june17-feb18.csv', 'may-nov19.csv', 'sep-dec18.csv', 'mar-aug18.csv', 'jan-may17.csv']
#                                                     unique_key  \
# trip_start_timestamp
# 2019-01-15 15:30:00   4c7faafbb9100aeb85e68f93fdece49b49db5c16
# 2019-01-19 13:30:00   977e465c878cd5337c2215e291ecf091cf2ef4a6
# 2019-01-24 07:15:00   f9eb08f49f09e56188333a95bea1d9d7220a79a9
# 2019-02-07 21:45:00   6c40ff49c9e05b30bef35ba2c0c0639fe3506127
# 2019-02-20 18:00:00   4c0c28580737e54f83246154655e06344e27897c
# ...                                                        ...
# 2017-03-27 13:15:00   e0c420b88c3eb7dcd2f4dc5549f42d8110ec0b38
# 2017-03-28 19:00:00   9cc83c478f6b856316e744fbef0b2be8dfa1a85c
# 2017-03-27 14:00:00   95e2202a1a6e3c6cd92012d666d871657355fc67
# 2017-03-27 13:00:00   2787788e87590c6547e9c19d6d945b16369ea0d8
# 2017-03-02 15:30:00   62b415d9316ce188138207a95da89f352d0d2dc6
#
#                                                                 taxi_id  \
# trip_start_timestamp
# 2019-01-15 15:30:00   07795ccd21974e03b1b86b908541d1a3622b075ad46eb6...
# 2019-01-19 13:30:00   84dab24222c24f99f6c543a5d02e5b47940df071fef3ed...
# 2019-01-24 07:15:00   15ba3f3c77572f9fe6f7cd47e70fa31af10194449cc975...
# 2019-02-07 21:45:00   b259515344f28837cc7546ff185da59066c4aa0c2ad490...
# 2019-02-20 18:00:00   6551ba527f916e0b8187165d7e61705fc2641c9b3afd69...
# ...                                                                 ...
# 2017-03-27 13:15:00   1de34714972b96b5c1ca74ac6c6d0d4b76fc90319501e2...
# 2017-03-28 19:00:00   6b13f64954003e46e0831bab52e2593cacb51d69a49be6...
# 2017-03-27 14:00:00   1de34714972b96b5c1ca74ac6c6d0d4b76fc90319501e2...
# 2017-03-27 13:00:00   1de34714972b96b5c1ca74ac6c6d0d4b76fc90319501e2...
# 2017-03-02 15:30:00   a6a548e2540f32e2256ab1cc100f38e8c0769484273c06...
#
#                      trip_start_timestamp  trip_end_timestamp  trip_seconds  \
# trip_start_timestamp
# 2019-01-15 15:30:00   2019-01-15 15:30:00 2019-01-15 15:30:00           1.0
# 2019-01-19 13:30:00   2019-01-19 13:30:00 2019-01-19 13:30:00          19.0
# 2019-01-24 07:15:00   2019-01-24 07:15:00 2019-01-24 07:30:00         328.0
# 2019-02-07 21:45:00   2019-02-07 21:45:00 2019-02-07 21:45:00         213.0
# 2019-02-20 18:00:00   2019-02-20 18:00:00 2019-02-20 18:00:00         348.0
# ...                                   ...                 ...           ...
# 2017-03-27 13:15:00   2017-03-27 13:15:00 2017-03-27 13:30:00         280.0
# 2017-03-28 19:00:00   2017-03-28 19:00:00 2017-03-28 19:00:00           3.0
# 2017-03-27 14:00:00   2017-03-27 14:00:00 2017-03-27 14:15:00         605.0
# 2017-03-27 13:00:00   2017-03-27 13:00:00 2017-03-27 13:00:00         142.0
# 2017-03-02 15:30:00   2017-03-02 15:30:00 2017-03-02 15:45:00         520.0
#
#                       trip_miles  pickup_community_area  \
# trip_start_timestamp
# 2019-01-15 15:30:00          0.0                     14
# 2019-01-19 13:30:00          0.1                     14
# 2019-01-24 07:15:00          1.1                     14
# 2019-02-07 21:45:00          0.9                     14
# 2019-02-20 18:00:00          0.9                     14
# ...                          ...                    ...
# 2017-03-27 13:15:00          0.7                      6
# 2017-03-28 19:00:00          0.0                      6
# 2017-03-27 14:00:00          1.6                      6
# 2017-03-27 13:00:00          0.5                      6
# 2017-03-02 15:30:00          1.9                      4
#
#                       dropoff_community_area  fare  tips  tolls  extras  \
# trip_start_timestamp
# 2019-01-15 15:30:00                       14  3.25   0.0    NaN     0.0
# 2019-01-19 13:30:00                       14  3.50   0.0    NaN     0.0
# 2019-01-24 07:15:00                       14  6.00   0.0    NaN     0.0
# 2019-02-07 21:45:00                       14  5.50   0.0    NaN     0.0
# 2019-02-20 18:00:00                       14  6.00   0.0    NaN     0.0
# ...                                      ...   ...   ...    ...     ...
# 2017-03-27 13:15:00                        6  5.50   1.0    NaN     0.0
# 2017-03-28 19:00:00                        6  3.25   0.0    NaN     0.0
# 2017-03-27 14:00:00                        6  8.25   0.0    NaN     0.0
# 2017-03-27 13:00:00                        6  4.50   0.0    NaN     0.0
# 2017-03-02 15:30:00                       77  8.25   0.0    NaN     0.0
#
#                       trip_total payment_type
# trip_start_timestamp
# 2019-01-15 15:30:00         3.25         Cash
# 2019-01-19 13:30:00         3.50         Cash
# 2019-01-24 07:15:00         6.00         Cash
# 2019-02-07 21:45:00         5.50         Cash
# 2019-02-20 18:00:00         6.00         Cash
# ...                          ...          ...
# 2017-03-27 13:15:00         6.50  Credit Card
# 2017-03-28 19:00:00         3.25         Cash
# 2017-03-27 14:00:00         8.25         Cash
# 2017-03-27 13:00:00         4.50         Cash
# 2017-03-02 15:30:00         8.25         Cash
#
# [7665012 rows x 14 columns]
# trip_start_timestamp
# 2019-01-15 15:30:00    14
# 2019-01-19 13:30:00    14
# 2019-01-24 07:15:00    14
# 2019-02-07 21:45:00    14
# 2019-02-20 18:00:00    14
#                        ..
# 2017-03-27 13:15:00     6
# 2017-03-28 19:00:00     6
# 2017-03-27 14:00:00     6
# 2017-03-27 13:00:00     6
# 2017-03-02 15:30:00    77
# Name: dropoff_community_area, Length: 7665002, dtype: int64
# trip_start_timestamp
# 2019-01-15 15:30:00    14
# 2019-01-19 13:30:00    14
# 2019-01-24 07:15:00    14
# 2019-02-07 21:45:00    14
# 2019-02-20 18:00:00    14
#                        ..
# 2017-03-27 13:15:00     6
# 2017-03-28 19:00:00     6
# 2017-03-27 14:00:00     6
# 2017-03-27 13:00:00     6
# 2017-03-02 15:30:00    77
# Name: dropoff_community_area, Length: 5940047, dtype: int64
# trip_start_timestamp
# 2019-02-21 16:00:00     8
# 2019-02-20 00:00:00    32
# 2019-02-17 16:00:00     8
# 2019-02-23 05:45:00     6
# 2019-02-20 00:00:00    77
#                        ..
# 2018-11-04 01:45:00     8
# 2018-11-04 01:45:00    32
# 2018-11-04 02:00:00     4
# 2018-11-04 02:00:00     2
# 2018-11-04 02:00:00     6
# Name: dropoff_community_area, Length: 388, dtype: int64
# <IPython.core.autocall.ZMQExitAutocall object at 0x10ca5d910>
# <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10ca1b1d0>>
# 4
# <module 'importlib' from '/usr/local/anaconda3/lib/python3.7/importlib/__init__.py'>
# trip_start_timestamp
# 2019-01-15 15:30:00    False
# 2019-01-19 13:30:00    False
# 2019-01-24 07:15:00    False
# 2019-02-07 21:45:00    False
# 2019-02-20 18:00:00    False
#                        ...
# 2017-03-27 13:15:00    False
# 2017-03-28 19:00:00    False
# 2017-03-27 14:00:00    False
# 2017-03-27 13:00:00    False
# 2017-03-02 15:30:00    False
# Name: trip_miles, Length: 7665012, dtype: bool
# ['Dropoff Distribution of Trip Seconds NAN Values', 'Dropoff Distribution']
# <module 'math' from '/usr/local/anaconda3/lib/python3.7/lib-dynload/math.cpython-37m-darwin.so'>
# <module 'mapGeneration' from '/Users/alexisgaziello/Google Drive/Data Prep and Analysis/Code/project_CSP_MATH_571/src/mapGeneration/mapGeneration.py'>
# 10
# name
# <module 'numpy' from '/usr/local/anaconda3/lib/python3.7/site-packages/numpy/__init__.py'>
# <module 'os' from '/usr/local/anaconda3/lib/python3.7/os.py'>
# /Users/alexisgaziello/Google Drive/Data Prep and Analysis/Code/project_CSP_MATH_571/src
# /Users/alexisgaziello/Google Drive/Data Prep and Analysis/DataSets/trips/
# /Users/alexisgaziello/Google Drive/Data Prep and Analysis/Code/project_CSP_MATH_571/src/mapGeneration/mapGeneration.py
# <module 'pandas' from '/usr/local/anaconda3/lib/python3.7/site-packages/pandas/__init__.py'>
# <module 'matplotlib.pyplot' from '/usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py'>
# 1167
# <IPython.core.autocall.ZMQExitAutocall object at 0x10ca5d910>
# They are the same rows! :)
# /
# <module 'seaborn' from '/usr/local/anaconda3/lib/python3.7/site-packages/seaborn/__init__.py'>
# ModuleSpec(name='mapGeneration', loader=<_frozen_importlib_external.SourceFileLoader object at 0x1a5c0df0d0>, origin='/Users/alexisgaziello/Google Drive/Data Prep and Analysis/Code/project_CSP_MATH_571/src/mapGeneration/mapGeneration.py')
# <module 'sys' (built-in)>
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x1abde932d0>
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x1a9f09fa90>
# trip_start_timestamp
# 2017-01-31    100.000000
# 2017-02-28    100.000000
# 2017-03-31    100.000000
# 2017-04-30    100.000000
# 2017-05-31    100.000000
# 2017-06-30    100.000000
# 2017-07-31    100.000000
# 2017-08-31    100.000000
# 2017-09-30    100.000000
# 2017-10-31    100.000000
# 2017-11-30    100.000000
# 2017-12-31    100.000000
# 2018-01-31    100.000000
# 2018-02-28    100.000000
# 2018-03-31    100.000000
# 2018-04-30    100.000000
# 2018-05-31    100.000000
# 2018-06-30    100.000000
# 2018-07-31     99.986783
# 2018-08-31     99.841560
# 2018-09-30     99.557881
# 2018-10-31     95.434630
# 2018-11-30     82.873078
# 2018-12-31     70.362760
# 2019-01-31     53.819516
# 2019-02-28     35.722084
# 2019-03-31     27.626950
# 2019-04-30     24.550631
# 2019-05-31      0.321534
# 2019-06-30      0.001697
# 2019-07-31      0.000000
# 2019-08-31      0.000604
# 2019-09-30      0.000000
# 2019-10-31      0.000543
# Freq: M, dtype: float64
