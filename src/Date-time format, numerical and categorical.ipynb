# %%
pwd
# Out:
# '/Users/anurag_chandra'

# %%
import os
os.chdir('/Users/anurag_chandra/Downloads')

# %%
import pandas as pd
df = pd.read_csv('dataset_final.csv')

# %%
df.head()
# Out:
#   trip_start_timestamp  pickup_community_area  Trips  temperature  \
# 0  2017-01-16 00:00:00                      1      1         30.0
# 1  2017-01-16 00:00:00                      2      0         30.0
# 2  2017-01-16 00:00:00                      3      4         30.0
# 3  2017-01-16 00:00:00                      4      3         30.0
# 4  2017-01-16 00:00:00                      5      2         30.0
#
#    relative_humidity  wind_direction  wind_speed  precipitation daytype  \
# 0               78.4           130.0         4.0            0.0       U
# 1               78.4           130.0         4.0            0.0       U
# 2               78.4           130.0         4.0            0.0       U
# 3               78.4           130.0         4.0            0.0       U
# 4               78.4           130.0         4.0            0.0       U
#
#   sky_level  ... Fare Last Month  Tips Last Month  pickup_community_area.1  \
# ...

# %%
df['Dates'] = pd.to_datetime(df['trip_start_timestamp']).dt.date

# %%
df['Time'] = pd.to_datetime(df['trip_start_timestamp']).dt.time

# %%
df
# Out:
#         trip_start_timestamp  pickup_community_area  Trips  temperature  \
# 0                 2017-01-16                      1      1         30.0
# 1                 2017-01-16                      2      0         30.0
# 2                 2017-01-16                      3      4         30.0
# 3                 2017-01-16                      4      3         30.0
# 4                 2017-01-16                      5      2         30.0
# 5                 2017-01-16                      6     33         30.0
# 6                 2017-01-16                      7     11         30.0
# 7                 2017-01-16                      8     58         30.0
# 8                 2017-01-16                      9      0         30.0
# 9                 2017-01-16                     10      0         30.0
# 10                2017-01-16                     11      1         30.0
# 11                2017-01-16                     12      0         30.0
# ...

# %%
df['day'] = df['trip_start_timestamp'].dt.day
df['month'] = df['trip_start_timestamp'].dt.month
df['year'] = df['trip_start_timestamp'].dt.year

# %%
df.head()
# Out:
#   trip_start_timestamp  pickup_community_area  Trips  temperature  \
# 0           2017-01-16                      1      1         30.0
# 1           2017-01-16                      2      0         30.0
# 2           2017-01-16                      3      4         30.0
# 3           2017-01-16                      4      3         30.0
# 4           2017-01-16                      5      2         30.0
#
#    relative_humidity  wind_direction  wind_speed  precipitation daytype  \
# 0               78.4           130.0         4.0            0.0       U
# 1               78.4           130.0         4.0            0.0       U
# 2               78.4           130.0         4.0            0.0       U
# 3               78.4           130.0         4.0            0.0       U
# 4               78.4           130.0         4.0            0.0       U
#
#   sky_level  ... Trips 2 Weeks Ago (Same Hour)  Day Name  Month  Hour  \
# ...

# %%
df.drop(columns ='Dates')
# Out:
#         trip_start_timestamp  pickup_community_area  Trips  temperature  \
# 0                 2017-01-16                      1      1         30.0
# 1                 2017-01-16                      2      0         30.0
# 2                 2017-01-16                      3      4         30.0
# 3                 2017-01-16                      4      3         30.0
# 4                 2017-01-16                      5      2         30.0
# 5                 2017-01-16                      6     33         30.0
# 6                 2017-01-16                      7     11         30.0
# 7                 2017-01-16                      8     58         30.0
# 8                 2017-01-16                      9      0         30.0
# 9                 2017-01-16                     10      0         30.0
# 10                2017-01-16                     11      1         30.0
# 11                2017-01-16                     12      0         30.0
# ...

# %%
df.describe()
# Out:
#        pickup_community_area         Trips   temperature  relative_humidity  \
# count           1.920149e+06  1.920149e+06  1.920149e+06       1.920149e+06
# mean            3.900000e+01  2.323080e+00  5.201538e+01       6.747079e+01
# std             2.222612e+01  1.303216e+01  2.058580e+01       1.718329e+01
# min             1.000000e+00 -1.280000e+02 -2.310000e+01       1.223000e+01
# 25%             2.000000e+01  0.000000e+00  3.600000e+01       5.551000e+01
# 50%             3.900000e+01  0.000000e+00  5.200000e+01       6.864000e+01
# 75%             5.800000e+01  1.000000e+00  7.000000e+01       8.127000e+01
# max             7.700000e+01  1.270000e+02  9.700000e+01       1.000000e+02
#
#        wind_direction    wind_speed  precipitation  Fare Last Month  \
# count    1.920149e+06  1.920149e+06   1.920149e+06     1.920149e+06
# mean     1.793497e+02  8.402734e+00   8.645666e-02     3.510404e+04
# std      1.099069e+02  4.542100e+00   3.684004e-01     1.136233e+05
# ...

# %%
cols = df.columns

# %%
numerical_cols = ['pickup_community_area', 'Trips', 'temperature', 'relative_humidity','wind_speed','precipitation','Fare Last Month',
            'Tips Last Month','pickup_community_area.1','Trips Last Hour','Trips Last Week (Same Hour)','Trips 2 Weeks Ago (Same Hour)']

# %%
categorical_cols = list(set(cols) - set(numerical_cols))

# %%
categorical_cols
# Out:
# ['wind_direction',
#  'trip_start_timestamp.1',
#  'daytype',
#  'Quarter',
#  'year',
#  'trip_start_timestamp',
#  'Hour',
#  'month',
#  'sky_level',
#  'Month',
#  'Day Name',
#  'Time',
#  'day',
#  'Dates']
